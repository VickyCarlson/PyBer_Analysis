# %%
# %matplotlib inline

# %%
# Import dependencies.
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# Set the x-axis to a list (array) of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis, color="green", linewidth=2, marker='d', label='Boston')
ax.legend(["Boston"], labelcolor='green')
ax.grid()
ax.set_ylim(0, 45)
ax.set_title("Pyber Fare by Month")
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
# Out:
# Text(0, 0.5, 'Fare($)')

# %%
# Create the plot with ax.plt()
ax = plt.axes()
#ax.plot(x_axis, y_axis)
#Change Line Color
ax.plot(x_axis, y_axis, color="green", linewidth=2, marker='d')
ax.legend(["Boston"], labelcolor="green")

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot using MATLAB method.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
#Create a bar chart using the MATLAB method.
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a Vertical bar chart
# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create a Horizontal bar chart
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# If you want the data on opposite axes, switch the arguments in the barh() function and run the cell again:

# Create the plot
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create a Horizontal bar chart and invert the axis so January is on top
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
#Using the Matplotlib MATLAB plotting approach, make the following changes:

#Change the bar colors to magenta.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')

#Add a title and axes labels.
plt.xlabel("Date")
plt.ylabel("Fare($)")

#Create a title.
plt.title("PyBer Fare by Month")

#Add a legend for the city of Boston.
plt.legend()

#Invert the y-axis so that January is at the top.
plt.gca().invert_yaxis()

# %%
#Create Bar Charts Using the Object-Oriented Approach

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Change the axis, add legend for Chicago, add title and axes labels, change bar color to cyan. Invert y-axis so January is on top.
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color = 'cyan')
ax.legend(["Chicago"])
ax.set_title("Pyber Fare by Month")
ax.set_ylabel("Date")
ax.set_xlabel("Fare($)")
plt.gca().invert_yaxis()

# %%
#Import matplotlib.pyplot as plt

x = [50, 42, 39, 34, 32, 48, 22, 17, 8, 13]
y =[17, 19, 21, 22, 24, 23, 34, 31, 43, 35]

plt.scatter(x, y, c='green', marker='x', s=x) 
#s is for size. In this case, it will set all marker sizes to 100, but we could set markers to different sizes.
#You can set s=x (list of x-axis – has to be the same number of markers that there are. The more rides there are, the bigger the marker will be)
plt.xlabel('Total Number of Rides (Per City)')
plt.ylabel('Average Fare ($)')
plt.title('Average Fare vs Total Rides')
plt.show()

# %%
#Make scatterplot using the plt.plot() method
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Include the 'o' to make it a scatterplot.
plt.plot(x_axis, y_axis, 'o')

# %%
#Make scatterplot using the plt.scatter() method
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]


plt.scatter(x_axis, y_axis)

# %%
#Make scatterplot using the plt.scatter() method
# Change the color of the markers to red.
# Add a legend for the city of Chicago.
# Add a title and axes labels.
# Switch the axis so that the Fare($) data is on the x-axis.
# Add a limit for the x-axis data.
# Invert the y-axis so that January is at the top.

# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]


plt.scatter(y_axis, x_axis, color='red')
plt.title("PLT Plot")
plt.xlabel("Fare($)")
plt.ylabel("Months")
plt.gca().invert_yaxis()

# %%
# Create bubble plot with size of marker equal to y values. 
plt.scatter(x_axis, y_axis, s=y_axis)

# %%
# Create bubble plot with size of marker equal to y values. Make markers larger by iterating through y axis multiplying data point by 3.
plt.scatter(x_axis, y_axis, s=y_axis_larger)

y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9832/2895342963.py in <module>
#       1 # Create bubble plot with size of marker equal to y values. Make markers larger by iterating through y axis multiplying data point by 3.
# ----> 2 plt.scatter(x_axis, y_axis, s=y_axis_larger)
#       3
#       4 y_axis_larger = []
#       5 for data in y_axis:
#
# NameError: name 'y_axis_larger' is not defined

# %%
# Create bubble plot -- Make markers larger with list comprehension.
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
#Create a Scatter Plot Using the Object-Oriented Interface

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
# Create a Bubble Plot Using the Object-Oriented Interface

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
#Using the object-oriented approach, make the following changes to your bubble chart:
#Change the color of the markers to sky blue.
#Change the size of the markers to 5 times each data point.
#Make the color 20% transparent.
#Add a black edge color to the circles.
#Make the linewidth of the circles 2 points.
#Add a legend for the city of Boston.
#Add a title.
#Switch the axis so that the Fare($) data is on the x-axis.
#Add a limit for the x-axis data.
#Invert the y-axis so that January is at the top.

fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, s = [i * 5 for i in y_axis], edgecolor='black', alpha=0.8, color='skyblue', linewidths=2)
ax.set_xlim([0, 60])
ax.legend(["Boston"])
ax.set_title("Pyber Fare by Month")
ax.set_ylabel("Date")
ax.set_xlabel("Fare($)")
plt.gca().invert_yaxis()

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d09b848730>,
#   <matplotlib.patches.Wedge at 0x1d09b84fca0>,
#   <matplotlib.patches.Wedge at 0x1d09b84fd90>,
#   <matplotlib.patches.Wedge at 0x1d09b840670>,
#   <matplotlib.patches.Wedge at 0x1d09b8e0a60>,
#   <matplotlib.patches.Wedge at 0x1d09b8e0a90>,
#   <matplotlib.patches.Wedge at 0x1d09b8e0220>,
#   <matplotlib.patches.Wedge at 0x1d09b74f160>,
#   <matplotlib.patches.Wedge at 0x1d09b74f730>,
#   <matplotlib.patches.Wedge at 0x1d09b7c0610>,
#   <matplotlib.patches.Wedge at 0x1d09b7b19a0>,
#   <matplotlib.patches.Wedge at 0x1d09b69e370>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1d09cf4db80>,
#   <matplotlib.patches.Wedge at 0x1d09cf5b340>,
#   <matplotlib.patches.Wedge at 0x1d09cf5ba60>,
#   <matplotlib.patches.Wedge at 0x1d09cf681c0>,
#   <matplotlib.patches.Wedge at 0x1d09cf688e0>,
#   <matplotlib.patches.Wedge at 0x1d09cf68fd0>,
#   <matplotlib.patches.Wedge at 0x1d09cf75760>,
#   <matplotlib.patches.Wedge at 0x1d09cf75e80>,
#   <matplotlib.patches.Wedge at 0x1d09cf835e0>,
#   <matplotlib.patches.Wedge at 0x1d09cf83d00>,
#   <matplotlib.patches.Wedge at 0x1d09cf8f460>,
#   <matplotlib.patches.Wedge at 0x1d09cf8fb80>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.3293082697128627, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452758, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.2333875250754619, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.4609812999807629, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065236, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883322, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.12730228640479738, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Syntax: Axes.pie(self, x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, 
#shadow=False, labeldistance=1.1, startangle=None, radius=None, counterclock=True, wedgeprops=None, 
#textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, data=None)

#Using the object-oriented approach, make the following changes to the pie chart:
#Add a percentage to one decimal place to each wedge of the pie.
#Increase the figure size to 8x8.
#Explode the two highest percentage months.
#Add a shadow.
#Add a start angle so that January is at the top.
#Reverse the order so that the month order is in a clockwise direction.
#Add new colors of your own choosing or use the colors from the previous pie chart.


fig, ax = plt.subplots(figsize=(8, 8))
colorvalues = ("red", "lavender", "violet", "aquamarine", "turquoise", "green", "yellowgreen", "greenyellow", 
          "yellow", "orange", "gold", "indianred")
explode_values = (0, 0, .3, 0, 0, 0, .3, 0, 0, 0, 0, 0)
ax.pie(y_axis, labels=x_axis, shadow=True, startangle=265, explode=explode_values, colors=colorvalues,
    autopct='%.1f%%')
plt.gca().invert_yaxis()
